# %%
run top500analysis.py
# Out:
# ################## June2022 CPU Distribution #####################
# Unique CPU Chip Manufacturers:  109
#
# INTEL Processors:  388
#
# AMD Processors:  92
#
# IBM Processors:  7
#
# Other Processors:  13
# ################## June2022 GPU Distribution #####################
# Unique GPU/Accelerator Chip Manufacturers:  26
#
# NVIDIA GPU/ACCs: make up 154 / 168 GPUs/Co-Processor Accelerators
#  or,  0.917 %
# ################## June2022 HETEROGENEITY  ##################
# CPU-Only Machines:  332
#
# Heterogeneous Machines:  168
# ################## June2011 HETEROGENEITY  ##################
# CPU-Only Machines:  481
#
# Heterogeneous Machines:  19
# June2022 Ratio of CPU-GPU Machines vs CPU only:  0.336
#
# June2011 Ratio of CPU-GPU Machines vs CPU only:  0.038
#
# June 2011 - June 2022 increase in heterogeneity:
# 784%
#
# ############## Power vs Performance June 2022 ##################
# Power vs Performance, Hover for Machine Info
# ...

# %%
# top 5 most effecient machines
df_e = df_june22[['name', 'rank', 'energyefficiencygflopswatts']] 
df_efficiency = df_e.dropna()
df_efficiency_sorted = df_efficiency.sort_values('energyefficiencygflopswatts', ascending=False)
df_efficiency_sorted.head(5)
#df2=df_efficient.nlargest(1,['energyefficiencygflopswatts'])
#print(df2)

# %%
conda install -c conda-forge python-kaleido

# %%
df_june22['rmaxbynmax'] = df_june22.rmaxtflops / df_june22.nmax
df_june22.rmaxbynmax
